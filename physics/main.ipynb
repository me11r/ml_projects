# %%
from vpython import *
# Out:
# <div id="glowscript" class="glowscript"></div>

# %%
scene1 = canvas(title="P69: Cube of Spheres")

L = 3 
R_sphere = 0.5

for x in [-L, L]:
    for y in [-L, L]:
        for z in [-L, L]:
            current_color = color.orange if (x + y + z) > 0 else color.red
            sphere(pos=vector(x, y, z), radius=R_sphere, color=current_color)

arrow(pos=vector(-L, -L, -L), axis=vector(2*L, 2*L, 2*L), color=color.green, shaftwidth=0.2)
# Out:
# <div id="glowscript" class="glowscript"></div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 10
#       8         for z in [-L, L]:
#       9             current_color = color.orange if (x + y + z) > 0 else color.red
# ---> 10             sphere(pos=vector(x, y, z), radius=R_sphere, color=current_color)
#      12 arrow(pos=vector(-L, -L, -L), axis=vector(2*L, 2*L, 2*L), color=color.green, shaftwidth=0.2)
#
# File /usr/local/lib/python3.14/site-packages/vpython/vpython.py:1189, in sphere.__init__(self, **args)
#    1187 args['_default_size'] = vector(2,2,2)
#    1188 args['_objName'] = "sphere"
# -> 1189 super(sphere, self).setup(args)
#    1190 self._sizing = False
#
# File /usr/local/lib/python3.14/site-packages/vpython/vpython.py:612, in standardAttributes.setup(self, args)
#     611 def setup(self, args):
# --> 612     super(standardAttributes, self).__init__()
#     613     self._constructing = True  ## calls to setters are from constructor
#     615     objName = self._objName = args['_objName']  ## identifies object type
#
# File /usr/local/lib/python3.14/site-packages/vpython/vpython.py:265, in baseObj.__init__(self, **kwargs)
#     262 if not (baseObj._view_constructed or
#     263         baseObj._canvas_constructing):
#     264     if _isnotebook:
# --> 265         from .with_notebook import _
#     266     else:
#     267         from .no_notebook import _
#
# File /usr/local/lib/python3.14/site-packages/vpython/with_notebook.py:154
#     152 baseObj.glow = GlowWidget(wsport=__SOCKET_PORT, wsuri='/ws')
#     153 while (not wsConnected):
# --> 154     time.sleep(0.1)          # wait for websocket to connect
#     156 baseObj.trigger()  # start the trigger ping-pong process
#     159 # Same justification as above for removing the ipykernel check.
#     160 # There was also an IPython version check for >=4, which was
#     161 # released in Nov 2015. Ok to stop supporting in 2.019 I think.
#
# KeyboardInterrupt:
