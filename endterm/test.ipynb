# %%
print("hello world")
# Out:
# hello world

# %%
a = 1
b = 2
print(a + b)
# Out:
# 3

# %%
a = ["hello world"]
print(a[0])
# Out:
# hello world

# %%
a = ["hello"]
b = ["world"]
print(a+b)
# Out:
# ['hello', 'world']
